# %% [markdown]
# https://matplotlib.org/3.1.1/tutorials/introductory/pyplot.html

# %%
import pandas as pd
import matplotlib.pyplot as plt
import math

# %%
def truncate(n, decimals=0):
    multiplier = 10 ** decimals
    return int(n * multiplier) / multiplier

# %%
df1=pd.read_csv("profile-200-exp8.xv", skiprows=(16), delimiter="\t",names=["x","y"])
df2=pd.read_csv("profile-200-exp9.xv", skiprows=(16), delimiter="\t",names=["x","y"])

# %% [markdown]
# Verifica as primeiras linhas, se importou direito

# %%
print (df1.head(2))
print (df2.head(2))
# Out:
#           x         y
# 0  0.939937  0.000000
# 1  0.980857  7.530981
#           x         y
# 0 -9.420371  0.000000
# 1 -9.378688  1.390916

# %% [markdown]
# Plota dados 'raw'

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.plot(df1["x"],df1["y"])
ax1.plot(df2["x"],df2["y"])
plt.show()

# %% [markdown]
# Tira os pontos das pontas:

# %%
#df1["x"]=df.loc[9:390,"x"]

# %% [markdown]
# Ajustes em X:

# %%
df1["x"]=df1["x"] + 15.1
df2["x"]=df2["x"] + 34

# %% [markdown]
# Coloca a fase gás em ZERO:

# %%
df["y"]=df["y"] +0

# %% [markdown]
# Imprime o máximo e o mínimo da curva

# %%
#perfil200.min()
y_min=truncate(df["y"].min(),2)
y_max=truncate(df["y"].max(),2)
delta=truncate((y_max - y_min),2)
print('min:',y_min, 'max:',y_max,'delta:',delta)
# Out:
# min: -25.73 max: 24.64 delta: 50.37

# %% [markdown]
# gera o gráfico

# %%
fig1 = plt.figure()
ax1 = fig1.add_subplot(111)
ax1.plot(df1["x"],df1["y"],'k')
ax1.plot(df2["x"],df2["y"],'r')
plt.show()

# %% [markdown]
# Aqui plot usando o Pandas:

# %%
p = df2.plot.line(x="x",y="y", color="black", grid=True, legend=False,figsize=(12,6))
p.set_title("PMF exp N-bulk", size=40)
p.set_xlabel("Distance / nm", size=20)
p.set_ylabel("Energy / KJ.mol-1", size=20)
p.text(3,-2,'min:'+str(y_min), size=20)
p.text(3,-2.5,'max:'+str(y_max),size=20)
p.text(3,-3,'delta:'+str(delta),size=20)
p.tick_params(labelsize=20)
plt.show()

# %% [markdown]
# Salva o plot em arquivo

# %%
p.get_figure().savefig("pmfEXP-N-bulk.20200904.png")
